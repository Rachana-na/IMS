# %%
products = {
    101 : {"name":"Monaco",                  "price":54,   "quantity":50,  "expiry":"20 oct 2023",  "brand":"Parle"},
    102 : {"name":"bour bon",                "price":22,   "quantity":100, "expiry":"12 jan 2022",  "brand":"britannia"},
    103 : {"name":"Good day",                "price":16,   "quantity":80,  "expiry":"10 mar 2023",  "brand":"britannia"},
    104 : {"name":"krack jack",              "price":54,   "quantity":90,  "expiry":"23 jun 2023",  "brand":"parle"},
    105 : {"name":"little hearts",           "price":17,   "quantity":50,  "expiry":"30 oct 2022",  "brand":"britannia"},
    106 : {"name":"Maggi",                   "price":80,   "quantity":40,  "expiry":"29 jan 2022",  "brand":"nestle"},
    107 : {"name":"Fogg",                    "price":125,  "quantity":30,  "expiry":"31 aug 2022",  "brand":"vinni cosmetics"},
    108 : {"name":"clean and clear",         "price":162,  "quantity":100, "expiry":"21 feb 2022",  "brand":"johnson"},
    109 : {"name":"Vaseline lotion",         "price":212,  "quantity":10,  "expiry":"28 dec 2021",  "brand":"hindustan unilever"},
    110 : {"name":"knoor soup",              "price":46,   "quantity":20,  "expiry":"01 jun 2022",  "brand":"hindustan unilever"},
    111 : {"name":"gits rice idli",          "price":105,  "quantity":30,  "expiry":"15 jul 2022",  "brand":"gits"},
    112 : {"name":"fortune oil",             "price":165,  "quantity":10,  "expiry":"02 dec 2021",  "brand":"fortune"},
    113 : {"name":"britannia bread",         "price":35,   "quantity":120, "expiry":"30 dec 2021",  "brand":"britannia"},
    114 : {"name":"pizza base bread",        "price":25,   "quantity":180, "expiry":"19 mar 2022",  "brand":"britannia"},
    115 : {"name":"milkybar",                "price":13,   "quantity":20,  "expiry":"19 feb 2022",  "brand":"nestle"},
    116 : {"name":"munch nuts",              "price":16,   "quantity":200, "expiry":"15 jan 2022",  "brand":"nestle"},
    117 : {"name":"poppins",                 "price":18,   "quantity":140, "expiry":"13 dec 2022",  "brand":"parle"},
    118 : {"name":"5star 3D",                "price":24,   "quantity":450, "expiry":"14 feb 2023",  "brand":"cadbury"},
    119 : {"name":"kitkat",                  "price":10,   "quantity":80,  "expiry":"20 dec 2023",  "brand":"nestle"},
    120 : {"name":"duracell batteries",      "price":144,  "quantity":20,  "expiry":"25 jan 2024",  "brand":"duracell"},
    121 : {"name":"garam masala",            "price":62,   "quantity":20,  "expiry":"22 jan 2023",  "brand":"everest"},
    122 : {"name":"pav bhaji masala",        "price":59,   "quantity":60,  "expiry":"20 dec 2024",  "brand":"everest"},
    123 : {"name":"appy fizz",               "price":13,   "quantity":70,  "expiry":"20 jun 2023",  "brand":"parle"},
    124 : {"name":"Coca-Cola",               "price":65,   "quantity":60,  "expiry":"22 jul 2023",  "brand":"Coca Cola"},
    125 : {"name":"red label",               "price":285,  "quantity":40,  "expiry":"20 nov 2023",  "brand":"hindustan unilever"},
    126 : {"name":"wheat atta",              "price":210,  "quantity":55,  "expiry":"20 jun 2024",  "brand":"aashirvaad"},
    127 : {"name":"coffee powder",           "price":55,   "quantity":150, "expiry":"15 jul 2022",  "brand":"bru"},
    128 : {"name":"soda",                    "price":13,   "quantity":100, "expiry":"10 aug 2023",  "brand":"bisleri"},
    129 : {"name":"mango drink",             "price":35,   "quantity":98,  "expiry":"31 jul 2022",  "brand":"maaza"},
    130 : {"name":"toothpaste",              "price":103,  "quantity":50,  "expiry":"31 jan 2022",  "brand":"dabur red"}
}

# %%
import json

# %%
js = json.dumps(products)

# %%
fd = open("products.json","w")
fd.write(js)
fd.close()

# %%
fd = open("products.json",'r')
read = fd.read()
fd.close()

# %%
products = json.loads(read)

# %%
products
# Out:
# {'101': {'name': 'Monaco',
#   'price': 54,
#   'quantity': 50,
#   'expiry': '20 oct 2023',
#   'brand': 'Parle'},
#  '102': {'name': 'bour bon',
#   'price': 22,
#   'quantity': 100,
#   'expiry': '12 jan 2022',
#   'brand': 'britannia'},
#  '103': {'name': 'Good day',
#   'price': 16,
#   'quantity': 80,
#   'expiry': '10 mar 2023',
#   'brand': 'britannia'},
#  '104': {'name': 'krack jack',
#   'price': 54,
#   'quantity': 90,
#   'expiry': '23 jun 2023',
#   'brand': 'parle'},
#  '105': {'name': 'little hearts',
#   'price': 17,
#   'quantity': 50,
#   'expiry': '30 oct 2022',
#   'brand': 'britannia'},
#  '106': {'name': 'Maggi',
#   'price': 80,
#   'quantity': 40,
#   'expiry': '29 jan 2022',
#   'brand': 'nestle'},
#  '107': {'name': 'Fogg',
#   'price': 125,
#   'quantity': 30,
#   'expiry': '31 aug 2022',
#   'brand': 'vinni cosmetics'},
#  '108': {'name': 'clean and clear',
#   'price': 162,
#   'quantity': 100,
#   'expiry': '21 feb 2022',
#   'brand': 'johnson'},
# ...

# %%
pro_id = input("Enter the Product ID: ")
name = input("Enter name of the Product: ")
price = int(input("Enter price per Item: "))
quan = int(input("Enter Quantity of the Product: "))
expiry = input("Enter expiry date of the Product: ")
brand = input("Enter Brand of the product: ")

products[pro_id] = {"name":name,"price":price,"quantity":quan,"expiry":expiry,"brand":brand}

js = json.dumps(products)

fd = open("products.json","w")
fd.write(js)
fd.close()
# Out:
# Enter the Product ID: 132
# Enter name of the Product: perk
# Enter price per Item: 10
# Enter Quantity of the Product: 200
# Enter expiry date of the Product: 20-sept-2024
# Enter Brand of the product: cadbury
